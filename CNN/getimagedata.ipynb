# %%
# (apenas se necessário) instalando a biblioteca Pillow (PIL) para captura dos pixels das imagens
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (11.2.1)

# %%
from PIL import Image
import requests
from io import BytesIO

# %%
# url da imagem
url = "https://upload.wikimedia.org/wikipedia/commons/7/73/Lion_waiting_in_Namibia.jpg"

# baixa a imagem
response = requests.get(url)

# abre em binário
img = Image.open(BytesIO(response.content))

# Usa getpixel() para acessar um pixel (ex: coordenada x=10, y=20)
x, y = 0, 0
pixel = img.getpixel((x, y))


print("Valores RGB do pixel em (",x,", ",y,"):", pixel)
print("R:", pixel[0])
print("G:", pixel[1])
print("B:", pixel[2])
# Out:
# Valores RGB do pixel em ( 0 ,  0 ): (144, 138, 88)
# R: 144
# G: 138
# B: 88

# %%
# pegando os pixels da imagem inteira
for x in range(img.width):
    for y in range(img.height):
        pixel = img.getpixel((x, y))
        print("Valores RGB do pixel em (",x,", ",y,"):", pixel)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Valores RGB do pixel em ( 1274 ,  760 ): (98, 88, 76)
# Valores RGB do pixel em ( 1274 ,  761 ): (81, 74, 68)
# Valores RGB do pixel em ( 1274 ,  762 ): (50, 46, 47)
# Valores RGB do pixel em ( 1274 ,  763 ): (33, 32, 37)
# Valores RGB do pixel em ( 1274 ,  764 ): (43, 46, 51)
# Valores RGB do pixel em ( 1274 ,  765 ): (60, 65, 69)
# Valores RGB do pixel em ( 1274 ,  766 ): (52, 60, 63)
# Valores RGB do pixel em ( 1274 ,  767 ): (35, 43, 46)
# Valores RGB do pixel em ( 1274 ,  768 ): (30, 31, 35)
# Valores RGB do pixel em ( 1274 ,  769 ): (36, 35, 40)
# Valores RGB do pixel em ( 1274 ,  770 ): (31, 32, 36)
# Valores RGB do pixel em ( 1274 ,  771 ): (32, 33, 37)
# Valores RGB do pixel em ( 1274 ,  772 ): (50, 51, 53)
# Valores RGB do pixel em ( 1274 ,  773 ): (92, 92, 92)
# Valores RGB do pixel em ( 1274 ,  774 ): (112, 107, 104)
# Valores RGB do pixel em ( 1274 ,  775 ): (81, 67, 64)
# Valores RGB do pixel em ( 1274 ,  776 ): (138, 118, 111)
# Valores RGB do pixel em ( 1274 ,  777 ): (134, 107, 96)
# Valores RGB do pixel em ( 1274 ,  778 ): (67, 35, 20)
# Valores RGB do pixel em ( 1274 ,  779 ): (72, 40, 19)
# Valores RGB do pixel em ( 1274 ,  780 ): (148, 117, 89)
# Valores RGB do pixel em ( 1274 ,  781 ): (219, 189, 155)
# Valores RGB do pixel em ( 1274 ,  782 ): (139, 111, 72)
# Valores RGB do pixel em ( 1274 ,  783 ): (94, 69, 38)
# Valores RGB do pixel em ( 1274 ,  784 ): (102, 83, 68)
# Valores RGB do pixel em ( 1274 ,  785 ): (66, 49, 41)
# Valores RGB do pixel em ( 1274 ,  786 ): (52, 35, 27)
# Valores RGB do pixel em ( 1274 ,  787 ): (87, 69, 59)
# Valores RGB do pixel em ( 1274 ,  788 ): (70, 52, 38)
# Valores RGB do pixel em ( 1274 ,  789 ): (103, 84, 69)
# Valores RGB do pixel em ( 1274 ,  790 ): (119, 100, 83)
# Valores RGB do pixel em ( 1274 ,  791 ): (134, 113, 94)
# Valores RGB do pixel em ( 1274 ,  792 ): (141, 119, 98)
# Valores RGB do pixel em ( 1274 ,  793 ): (145, 123, 100)
# Valores RGB do pixel em ( 1274 ,  794 ): (137, 113, 89)
# Valores RGB do pixel em ( 1274 ,  795 ): (115, 91, 67)
# Valores RGB do pixel em ( 1274 ,  796 ): (124, 100, 76)
# Valores RGB do pixel em ( 1274 ,  797 ): (133, 109, 85)
# Valores RGB do pixel em ( 1274 ,  798 ): (110, 86, 62)
# Valores RGB do pixel em ( 1274 ,  799 ): (65, 39, 14)
# Valores RGB do pixel em ( 1274 ,  800 ): (129, 102, 73)
# Valores RGB do pixel em ( 1274 ,  801 ): (162, 135, 105)
# Valores RGB do pixel em ( 1274 ,  802 ): (145, 120, 89)
# Valores RGB do pixel em ( 1274 ,  803 ): (136, 111, 80)
# Valores RGB do pixel em ( 1274 ,  804 ): (151, 126, 95)
# Valores RGB do pixel em ( 1274 ,  805 ): (140, 115, 84)
# Valores RGB do pixel em ( 1274 ,  806 ): (126, 103, 72)
# Valores RGB do pixel em ( 1274 ,  807 ): (127, 106, 77)
# Valores RGB do pixel em ( 1274 ,  808 ): (108, 91, 63)
# Valores RGB do pixel em ( 1274 ,  809 ): (78, 62, 36)
# Valores RGB do pixel em ( 1274 ,  810 ): (89, 77, 53)
# Valores RGB do pixel em ( 1274 ,  811 ): (115, 104, 84)
# Valores RGB do pixel em ( 1274 ,  812 ): (102, 95, 77)
# Valores RGB do pixel em ( 1274 ,  813 ): (67, 61, 47)
# Valores RGB do pixel em ( 1274 ,  814 ): (56, 52, 40)
# Valores RGB do pixel em ( 1274 ,  815 ): (82, 79, 70)
# Valores RGB do pixel em ( 1274 ,  816 ): (54, 55, 50)
# Valores RGB do pixel em ( 1274 ,  817 ): (34, 35, 37)
# Valores RGB do pixel em ( 1274 ,  818 ): (28, 28, 36)
# Valores RGB do pixel em ( 1274 ,  819 ): (30, 28, 39)
# Valores RGB do pixel em ( 1274 ,  820 ): (36, 32, 46)
# Valores RGB do pixel em ( 1274 ,  821 ): (35, 29, 39)
# Valores RGB do pixel em ( 1274 ,  822 ): (47, 36, 42)
# Valores RGB do pixel em ( 1274 ,  823 ): (91, 75, 75)
# Valores RGB do pixel em ( 1274 ,  824 ): (104, 84, 75)
# Valores RGB do pixel em ( 1274 ,  825 ): (124, 101, 85)
# Valores RGB do pixel em ( 1274 ,  826 ): (137, 112, 90)
# Valores RGB do pixel em ( 1274 ,  827 ): (138, 116, 93)
# Valores RGB do pixel em ( 1274 ,  828 ): (141, 124, 104)
# Valores RGB do pixel em ( 1274 ,  829 ): (102, 90, 74)
# Valores RGB do pixel em ( 1274 ,  830 ): (42, 35, 25)
# Valores RGB do pixel em ( 1274 ,  831 ): (35, 32, 27)
# Valores RGB do pixel em ( 1274 ,  832 ): (27, 29, 28)
# Valores RGB do pixel em ( 1274 ,  833 ): (34, 38, 41)
# Valores RGB do pixel em ( 1274 ,  834 ): (30, 31, 36)
# Valores RGB do pixel em ( 1274 ,  835 ): (40, 37, 46)
# Valores RGB do pixel em ( 1274 ,  836 ): (49, 41, 52)
# Valores RGB do pixel em ( 1274 ,  837 ): (52, 42, 51)
# Valores RGB do pixel em ( 1274 ,  838 ): (74, 63, 69)
# Valores RGB do pixel em ( 1274 ,  839 ): (90, 78, 80)
# Valores RGB do pixel em ( 1274 ,  840 ): (90, 76, 73)
# Valores RGB do pixel em ( 1274 ,  841 ): (80, 65, 58)
# Valores RGB do pixel em ( 1274 ,  842 ): (78, 66, 54)
# Valores RGB do pixel em ( 1274 ,  843 ): (99, 87, 75)
# Valores RGB do pixel em ( 1274 ,  844 ): (109, 99, 89)
# Valores RGB do pixel em ( 1274 ,  845 ): (86, 76, 67)
# Valores RGB do pixel em ( 1274 ,  846 ): (64, 53, 47)
# Valores RGB do pixel em ( 1274 ,  847 ): (67, 59, 56)
# Valores RGB do pixel em ( 1274 ,  848 ): (40, 36, 33)
# Valores RGB do pixel em ( 1274 ,  849 ): (38, 37, 35)
# Valores RGB do pixel em ( 1274 ,  850 ): (38, 34, 35)
# Valores RGB do pixel em ( 1274 ,  851 ): (38, 34, 35)
# Valores RGB do pixel em ( 1274 ,  852 ): (47, 41, 43)
# Valores RGB do pixel em ( 1274 ,  853 ): (60, 51, 54)
# Valores RGB do pixel em ( 1274 ,  854 ): (68, 56, 60)
# Valores RGB do pixel em ( 1274 ,  855 ): (70, 54, 57)
# Valores RGB do pixel em ( 1274 ,  856 ): (98, 78, 79)
# Valores RGB do pixel em ( 1274 ,  857 ): (128, 107, 102)
# Valores RGB do pixel em ( 1274 ,  858 ): (138, 114, 104)
# Valores RGB do pixel em ( 1274 ,  859 ): (134, 107, 90)
# Valores RGB do pixel em ( 1274 ,  860 ): (138, 110, 88)
# Valores RGB do pixel em ( 1274 ,  861 ): (136, 106, 78)
# Valores RGB do pixel em ( 1274 ,  862 ): (129, 98, 67)
# Valores RGB do pixel em ( 1274 ,  863 ): (129, 103, 68)
# Valores RGB do pixel em ( 1274 ,  864 ): (133, 115, 79)
# Valores RGB do pixel em ( 1274 ,  865 ): (95, 82, 50)
# Valores RGB do pixel em ( 1274 ,  866 ): (76, 65, 43)
# Valores RGB do pixel em ( 1274 ,  867 ): (58, 50, 39)
# Valores RGB do pixel em ( 1274 ,  868 ): (41, 36, 33)
# Valores RGB do pixel em ( 1274 ,  869 ): (35, 29, 33)
# Valores RGB do pixel em ( 1274 ,  870 ): (38, 32, 36)
# Valores RGB do pixel em ( 1274 ,  871 ): (60, 49, 53)
# Valores RGB do pixel em ( 1274 ,  872 ): (84, 70, 67)
# Valores RGB do pixel em ( 1274 ,  873 ): (61, 47, 38)
# Valores RGB do pixel em ( 1274 ,  874 ): (70, 54, 39)
# Valores RGB do pixel em ( 1274 ,  875 ): (85, 70, 51)
# Valores RGB do pixel em ( 1274 ,  876 ): (85, 72, 55)
# Valores RGB do pixel em ( 1274 ,  877 ): (95, 83, 67)
# Valores RGB do pixel em ( 1274 ,  878 ): (86, 79, 63)
# Valores RGB do pixel em ( 1274 ,  879 ): (50, 42, 29)
# Valores RGB do pixel em ( 1274 ,  880 ): (103, 94, 79)
# Valores RGB do pixel em ( 1274 ,  881 ): (105, 93, 77)
# Valores RGB do pixel em ( 1274 ,  882 ): (134, 121, 105)
# Valores RGB do pixel em ( 1274 ,  883 ): (120, 107, 91)
# Valores RGB do pixel em ( 1274 ,  884 ): (93, 76, 60)
# Valores RGB do pixel em ( 1274 ,  885 ): (103, 84, 67)
# Valores RGB do pixel em ( 1274 ,  886 ): (100, 77, 59)
# Valores RGB do pixel em ( 1274 ,  887 ): (75, 50, 30)
# Valores RGB do pixel em ( 1274 ,  888 ): (92, 64, 42)
# Valores RGB do pixel em ( 1274 ,  889 ): (103, 73, 47)
# Valores RGB do pixel em ( 1274 ,  890 ): (124, 90, 63)
# Valores RGB do pixel em ( 1274 ,  891 ): (134, 99, 69)
# Valores RGB do pixel em ( 1274 ,  892 ): (132, 96, 64)
# Valores RGB do pixel em ( 1274 ,  893 ): (137, 99, 63)
# Valores RGB do pixel em ( 1274 ,  894 ): (150, 112, 75)
# Valores RGB do pixel em ( 1274 ,  895 ): (160, 122, 85)
# Valores RGB do pixel em ( 1274 ,  896 ): (143, 105, 66)
# Valores RGB do pixel em ( 1274 ,  897 ): (151, 114, 70)
# Valores RGB do pixel em ( 1274 ,  898 ): (163, 129, 81)
# Valores RGB do pixel em ( 1274 ,  899 ): (177, 144, 93)
# Valores RGB do pixel em ( 1274 ,  900 ): (187, 154, 100)
# Valores RGB do pixel em ( 1274 ,  901 ): (182, 150, 93)
# Valores RGB do pixel em ( 1274 ,  902 ): (163, 132, 75)
# Valores RGB do pixel em ( 1274 ,  903 ): (147, 114, 60)
# Valores RGB do pixel em ( 1274 ,  904 ): (152, 119, 68)
# Valores RGB do pixel em ( 1274 ,  905 ): (169, 135, 87)
# Valores RGB do pixel em ( 1274 ,  906 ): (159, 123, 75)
# Valores RGB do pixel em ( 1274 ,  907 ): (180, 144, 96)
# Valores RGB do pixel em ( 1274 ,  908 ): (199, 161, 112)
# Valores RGB do pixel em ( 1274 ,  909 ): (184, 147, 94)
# Valores RGB do pixel em ( 1274 ,  910 ): (187, 148, 93)
# Valores RGB do pixel em ( 1274 ,  911 ): (184, 145, 86)
# Valores RGB do pixel em ( 1274 ,  912 ): (182, 146, 84)
# Valores RGB do pixel em ( 1274 ,  913 ): (178, 142, 82)
# Valores RGB do pixel em ( 1274 ,  914 ): (161, 124, 69)
# Valores RGB do pixel em ( 1274 ,  915 ): (162, 125, 73)
# Valores RGB do pixel em ( 1274 ,  916 ): (155, 114, 68)
# Valores RGB do pixel em ( 1274 ,  917 ): (175, 134, 90)
# Valores RGB do pixel em ( 1274 ,  918 ): (211, 169, 127)
# Valores RGB do pixel em ( 1274 ,  919 ): (173, 134, 91)
# Valores RGB do pixel em ( 1274 ,  920 ): (142, 105, 61)
# Valores RGB do pixel em ( 1274 ,  921 ): (121, 84, 40)
# Valores RGB do pixel em ( 1274 ,  922 ): (107, 72, 30)
# Valores RGB do pixel em ( 1274 ,  923 ): (125, 92, 51)
# Valores RGB do pixel em ( 1274 ,  924 ): (148, 116, 78)
# Valores RGB do pixel em ( 1274 ,  925 ): (147, 117, 83)
# Valores RGB do pixel em ( 1274 ,  926 ): (139, 110, 80)
# Valores RGB do pixel em ( 1274 ,  927 ): (141, 111, 85)
# Valores RGB do pixel em ( 1274 ,  928 ): (163, 131, 108)
# Valores RGB do pixel em ( 1274 ,  929 ): (152, 117, 95)
# Valores RGB do pixel em ( 1274 ,  930 ): (143, 108, 86)
# Valores RGB do pixel em ( 1274 ,  931 ): (150, 115, 93)
# Valores RGB do pixel em ( 1274 ,  932 ): (166, 131, 109)
# Valores RGB do pixel em ( 1274 ,  933 ): (152, 120, 97)
# Valores RGB do pixel em ( 1274 ,  934 ): (137, 105, 80)
# Valores RGB do pixel em ( 1274 ,  935 ): (159, 128, 100)
# Valores RGB do pixel em ( 1274 ,  936 ): (159, 128, 99)
# Valores RGB do pixel em ( 1274 ,  937 ): (165, 136, 106)
# Valores RGB do pixel em ( 1274 ,  938 ): (163, 134, 102)
# Valores RGB do pixel em ( 1274 ,  939 ): (141, 113, 76)
# Valores RGB do pixel em ( 1274 ,  940 ): (125, 97, 58)
# Valores RGB do pixel em ( 1274 ,  941 ): (143, 115, 75)
# Valores RGB do pixel em ( 1274 ,  942 ): (167, 139, 99)
# Valores RGB do pixel em ( 1274 ,  943 ): (170, 145, 104)
# Valores RGB do pixel em ( 1274 ,  944 ): (157, 134, 93)
# Valores RGB do pixel em ( 1274 ,  945 ): (172, 150, 109)
# Valores RGB do pixel em ( 1274 ,  946 ): (143, 122, 79)
# Valores RGB do pixel em ( 1274 ,  947 ): (132, 114, 68)
# Valores RGB do pixel em ( 1274 ,  948 ): (126, 109, 63)
# Valores RGB do pixel em ( 1274 ,  949 ): (144, 130, 85)
# Valores RGB do pixel em ( 1274 ,  950 ): (138, 125, 83)
# Valores RGB do pixel em ( 1274 ,  951 ): (121, 109, 71)
# Valores RGB do pixel em ( 1274 ,  952 ): (118, 105, 73)
# Valores RGB do pixel em ( 1274 ,  953 ): (128, 114, 87)
# Valores RGB do pixel em ( 1274 ,  954 ): (137, 123, 97)
# Valores RGB do pixel em ( 1274 ,  955 ): (131, 117, 91)
# Valores RGB do pixel em ( 1274 ,  956 ): (121, 107, 80)
# Valores RGB do pixel em ( 1274 ,  957 ): (130, 115, 84)
# Valores RGB do pixel em ( 1274 ,  958 ): (135, 121, 86)
# Valores RGB do pixel em ( 1274 ,  959 ): (125, 109, 73)
# Valores RGB do pixel em ( 1275 ,  0 ): (124, 105, 62)
# Valores RGB do pixel em ( 1275 ,  1 ): (120, 101, 58)
# Valores RGB do pixel em ( 1275 ,  2 ): (116, 99, 55)
# Valores RGB do pixel em ( 1275 ,  3 ): (116, 99, 55)
# Valores RGB do pixel em ( 1275 ,  4 ): (115, 101, 54)
# Valores RGB do pixel em ( 1275 ,  5 ): (119, 105, 56)
# Valores RGB do pixel em ( 1275 ,  6 ): (127, 113, 64)
# Valores RGB do pixel em ( 1275 ,  7 ): (135, 122, 70)
# Valores RGB do pixel em ( 1275 ,  8 ): (138, 122, 70)
# Valores RGB do pixel em ( 1275 ,  9 ): (148, 133, 78)
# Valores RGB do pixel em ( 1275 ,  10 ): (157, 140, 86)
# Valores RGB do pixel em ( 1275 ,  11 ): (162, 143, 87)
# Valores RGB do pixel em ( 1275 ,  12 ): (164, 143, 88)
# Valores RGB do pixel em ( 1275 ,  13 ): (168, 145, 91)
# Valores RGB do pixel em ( 1275 ,  14 ): (172, 150, 93)
# Valores RGB do pixel em ( 1275 ,  15 ): (175, 152, 98)
# Valores RGB do pixel em ( 1275 ,  16 ): (170, 147, 97)
# Valores RGB do pixel em ( 1275 ,  17 ): (171, 147, 99)
# Valores RGB do pixel em ( 1275 ,  18 ): (172, 148, 100)
# Valores RGB do pixel em ( 1275 ,  19 ): (174, 150, 102)
# Valores RGB do pixel em ( 1275 ,  20 ): (176, 152, 104)
# Valores RGB do pixel em ( 1275 ,  21 ): (177, 153, 107)
# Valores RGB do pixel em ( 1275 ,  22 ): (178, 154, 108)
# Valores RGB do pixel em ( 1275 ,  23 ): (180, 153, 110)
# Valores RGB do pixel em ( 1275 ,  24 ): (177, 150, 107)
# Valores RGB do pixel em ( 1275 ,  25 ): (178, 151, 108)
# Valores RGB do pixel em ( 1275 ,  26 ): (176, 148, 108)
# Valores RGB do pixel em ( 1275 ,  27 ): (172, 144, 104)
# Valores RGB do pixel em ( 1275 ,  28 ): (171, 143, 103)
# Valores RGB do pixel em ( 1275 ,  29 ): (173, 145, 105)
# Valores RGB do pixel em ( 1275 ,  30 ): (173, 145, 105)
# Valores RGB do pixel em ( 1275 ,  31 ): (172, 144, 105)
# Valores RGB do pixel em ( 1275 ,  32 ): (167, 142, 102)
# Valores RGB do pixel em ( 1275 ,  33 ): (167, 142, 102)
# Valores RGB do pixel em ( 1275 ,  34 ): (168, 143, 103)
# Valores RGB do pixel em ( 1275 ,  35 ): (170, 145, 105)
# Valores RGB do pixel em ( 1275 ,  36 ): (170, 145, 105)
# Valores RGB do pixel em ( 1275 ,  37 ): (170, 145, 104)
# Valores RGB do pixel em ( 1275 ,  38 ): (173, 148, 107)
# Valores RGB do pixel em ( 1275 ,  39 ): (177, 152, 111)
# Valores RGB do pixel em ( 1275 ,  40 ): (181, 156, 115)
# Valores RGB do pixel em ( 1275 ,  41 ): (181, 157, 113)
# Valores RGB do pixel em ( 1275 ,  42 ): (181, 157, 113)
# Valores RGB do pixel em ( 1275 ,  43 ): (181, 157, 113)
# Valores RGB do pixel em ( 1275 ,  44 ): (180, 156, 112)
# Valores RGB do pixel em ( 1275 ,  45 ): (180, 156, 112)
# Valores RGB do pixel em ( 1275 ,  46 ): (180, 156, 112)
# Valores RGB do pixel em ( 1275 ,  47 ): (180, 156, 112)
# Valores RGB do pixel em ( 1275 ,  48 ): (181, 154, 111)
# Valores RGB do pixel em ( 1275 ,  49 ): (181, 154, 111)
# Valores RGB do pixel em ( 1275 ,  50 ): (182, 155, 112)
# Valores RGB do pixel em ( 1275 ,  51 ): (183, 156, 113)
# Valores RGB do pixel em ( 1275 ,  52 ): (186, 159, 116)
# Valores RGB do pixel em ( 1275 ,  53 ): (188, 161, 118)
# Valores RGB do pixel em ( 1275 ,  54 ): (190, 163, 120)
# Valores RGB do pixel em ( 1275 ,  55 ): (192, 165, 122)
# Valores RGB do pixel em ( 1275 ,  56 ): (190, 163, 120)
# Valores RGB do pixel em ( 1275 ,  57 ): (190, 163, 120)
# Valores RGB do pixel em ( 1275 ,  58 ): (190, 163, 120)
# Valores RGB do pixel em ( 1275 ,  59 ): (191, 164, 121)
# Valores RGB do pixel em ( 1275 ,  60 ): (192, 165, 122)
# Valores RGB do pixel em ( 1275 ,  61 ): (194, 167, 124)
# Valores RGB do pixel em ( 1275 ,  62 ): (196, 169, 126)
# Valores RGB do pixel em ( 1275 ,  63 ): (197, 170, 127)
# Valores RGB do pixel em ( 1275 ,  64 ): (194, 167, 124)
# Valores RGB do pixel em ( 1275 ,  65 ): (194, 167, 124)
# Valores RGB do pixel em ( 1275 ,  66 ): (195, 168, 125)
# Valores RGB do pixel em ( 1275 ,  67 ): (195, 168, 125)
# Valores RGB do pixel em ( 1275 ,  68 ): (194, 167, 124)
# Valores RGB do pixel em ( 1275 ,  69 ): (195, 168, 125)
# Valores RGB do pixel em ( 1275 ,  70 ): (197, 170, 127)
# Valores RGB do pixel em ( 1275 ,  71 ): (199, 172, 129)
# Valores RGB do pixel em ( 1275 ,  72 ): (199, 172, 129)
# Valores RGB do pixel em ( 1275 ,  73 ): (200, 173, 130)
# Valores RGB do pixel em ( 1275 ,  74 ): (201, 174, 131)
# Valores RGB do pixel em ( 1275 ,  75 ): (203, 176, 133)
# Valores RGB do pixel em ( 1275 ,  76 ): (203, 176, 133)
# Valores RGB do pixel em ( 1275 ,  77 ): (203, 176, 133)
# Valores RGB do pixel em ( 1275 ,  78 ): (203, 176, 133)
# Valores RGB do pixel em ( 1275 ,  79 ): (203, 176, 133)
# Valores RGB do pixel em ( 1275 ,  80 ): (202, 175, 130)
# Valores RGB do pixel em ( 1275 ,  81 ): (205, 176, 132)
# Valores RGB do pixel em ( 1275 ,  82 ): (206, 177, 133)
# Valores RGB do pixel em ( 1275 ,  83 ): (205, 176, 132)
# Valores RGB do pixel em ( 1275 ,  84 ): (204, 175, 131)
# Valores RGB do pixel em ( 1275 ,  85 ): (202, 173, 129)
# Valores RGB do pixel em ( 1275 ,  86 ): (201, 173, 126)
# Valores RGB do pixel em ( 1275 ,  87 ): (202, 174, 127)
# Valores RGB do pixel em ( 1275 ,  88 ): (203, 175, 128)
# Valores RGB do pixel em ( 1275 ,  89 ): (203, 175, 128)
# Valores RGB do pixel em ( 1275 ,  90 ): (204, 176, 128)
# Valores RGB do pixel em ( 1275 ,  91 ): (205, 177, 129)
# Valores RGB do pixel em ( 1275 ,  92 ): (206, 178, 130)
# Valores RGB do pixel em ( 1275 ,  93 ): (207, 179, 131)
# Valores RGB do pixel em ( 1275 ,  94 ): (208, 180, 132)
# Valores RGB do pixel em ( 1275 ,  95 ): (208, 180, 132)
# Valores RGB do pixel em ( 1275 ,  96 ): (210, 180, 130)
# Valores RGB do pixel em ( 1275 ,  97 ): (210, 178, 129)
# Valores RGB do pixel em ( 1275 ,  98 ): (209, 177, 128)
# Valores RGB do pixel em ( 1275 ,  99 ): (207, 175, 126)
# Valores RGB do pixel em ( 1275 ,  100 ): (206, 174, 125)
# Valores RGB do pixel em ( 1275 ,  101 ): (207, 175, 126)
# Valores RGB do pixel em ( 1275 ,  102 ): (208, 176, 127)
# Valores RGB do pixel em ( 1275 ,  103 ): (208, 176, 127)
# Valores RGB do pixel em ( 1275 ,  104 ): (206, 174, 125)
# Valores RGB do pixel em ( 1275 ,  105 ): (207, 175, 126)
# Valores RGB do pixel em ( 1275 ,  106 ): (209, 177, 128)
# Valores RGB do pixel em ( 1275 ,  107 ): (209, 177, 128)
# Valores RGB do pixel em ( 1275 ,  108 ): (208, 176, 127)
# Valores RGB do pixel em ( 1275 ,  109 ): (208, 176, 127)
# Valores RGB do pixel em ( 1275 ,  110 ): (209, 177, 128)
# Valores RGB do pixel em ( 1275 ,  111 ): (210, 178, 127)
# Valores RGB do pixel em ( 1275 ,  112 ): (213, 182, 128)
# Valores RGB do pixel em ( 1275 ,  113 ): (213, 182, 128)
# Valores RGB do pixel em ( 1275 ,  114 ): (213, 182, 128)
# Valores RGB do pixel em ( 1275 ,  115 ): (211, 180, 126)
# Valores RGB do pixel em ( 1275 ,  116 ): (209, 179, 125)
# Valores RGB do pixel em ( 1275 ,  117 ): (208, 178, 124)
# Valores RGB do pixel em ( 1275 ,  118 ): (209, 179, 125)
# Valores RGB do pixel em ( 1275 ,  119 ): (210, 180, 126)
# Valores RGB do pixel em ( 1275 ,  120 ): (210, 183, 128)
# Valores RGB do pixel em ( 1275 ,  121 ): (210, 183, 128)
# Valores RGB do pixel em ( 1275 ,  122 ): (209, 182, 127)
# Valores RGB do pixel em ( 1275 ,  123 ): (209, 182, 127)
# Valores RGB do pixel em ( 1275 ,  124 ): (209, 182, 127)
# Valores RGB do pixel em ( 1275 ,  125 ): (211, 184, 129)
# Valores RGB do pixel em ( 1275 ,  126 ): (211, 186, 130)
# Valores RGB do pixel em ( 1275 ,  127 ): (212, 187, 131)
# Valores RGB do pixel em ( 1275 ,  128 ): (216, 189, 134)
# Valores RGB do pixel em ( 1275 ,  129 ): (218, 188, 136)
# Valores RGB do pixel em ( 1275 ,  130 ): (219, 189, 137)
# Valores RGB do pixel em ( 1275 ,  131 ): (219, 189, 137)
# Valores RGB do pixel em ( 1275 ,  132 ): (219, 189, 137)
# Valores RGB do pixel em ( 1275 ,  133 ): (218, 188, 136)
# Valores RGB do pixel em ( 1275 ,  134 ): (217, 187, 135)
# Valores RGB do pixel em ( 1275 ,  135 ): (217, 187, 135)
# Valores RGB do pixel em ( 1275 ,  136 ): (213, 183, 131)
# Valores RGB do pixel em ( 1275 ,  137 ): (213, 183, 131)
# Valores RGB do pixel em ( 1275 ,  138 ): (213, 183, 131)
# Valores RGB do pixel em ( 1275 ,  139 ): (213, 183, 131)
# Valores RGB do pixel em ( 1275 ,  140 ): (214, 184, 132)
# Valores RGB do pixel em ( 1275 ,  141 ): (215, 185, 133)
# Valores RGB do pixel em ( 1275 ,  142 ): (216, 186, 134)
# Valores RGB do pixel em ( 1275 ,  143 ): (216, 186, 134)
# Valores RGB do pixel em ( 1275 ,  144 ): (217, 187, 137)
# Valores RGB do pixel em ( 1275 ,  145 ): (217, 185, 136)
# Valores RGB do pixel em ( 1275 ,  146 ): (217, 185, 134)
# Valores RGB do pixel em ( 1275 ,  147 ): (217, 185, 134)
# Valores RGB do pixel em ( 1275 ,  148 ): (216, 184, 133)
# Valores RGB do pixel em ( 1275 ,  149 ): (216, 184, 133)
# Valores RGB do pixel em ( 1275 ,  150 ): (217, 185, 134)
# Valores RGB do pixel em ( 1275 ,  151 ): (217, 185, 134)
# Valores RGB do pixel em ( 1275 ,  152 ): (217, 186, 132)
# Valores RGB do pixel em ( 1275 ,  153 ): (218, 187, 133)
# Valores RGB do pixel em ( 1275 ,  154 ): (218, 187, 133)
# Valores RGB do pixel em ( 1275 ,  155 ): (219, 188, 134)
# Valores RGB do pixel em ( 1275 ,  156 ): (220, 189, 135)
# Valores RGB do pixel em ( 1275 ,  157 ): (221, 190, 136)
# Valores RGB do pixel em ( 1275 ,  158 ): (222, 191, 136)
# Valores RGB do pixel em ( 1275 ,  159 ): (222, 191, 136)
# Valores RGB do pixel em ( 1275 ,  160 ): (227, 198, 142)
# Valores RGB do pixel em ( 1275 ,  161 ): (226, 197, 141)
# Valores RGB do pixel em ( 1275 ,  162 ): (225, 196, 140)
# Valores RGB do pixel em ( 1275 ,  163 ): (224, 195, 139)
# Valores RGB do pixel em ( 1275 ,  164 ): (224, 195, 139)
# Valores RGB do pixel em ( 1275 ,  165 ): (224, 195, 139)
# Valores RGB do pixel em ( 1275 ,  166 ): (224, 195, 139)
# Valores RGB do pixel em ( 1275 ,  167 ): (225, 196, 140)
# Valores RGB do pixel em ( 1275 ,  168 ): (225, 196, 140)
# Valores RGB do pixel em ( 1275 ,  169 ): (223, 194, 138)
# Valores RGB do pixel em ( 1275 ,  170 ): (220, 191, 135)
# Valores RGB do pixel em ( 1275 ,  171 ): (218, 189, 133)
# Valores RGB do pixel em ( 1275 ,  172 ): (218, 189, 133)
# Valores RGB do pixel em ( 1275 ,  173 ): (219, 190, 134)
# Valores RGB do pixel em ( 1275 ,  174 ): (221, 192, 136)
# Valores RGB do pixel em ( 1275 ,  175 ): (223, 194, 138)
# Valores RGB do pixel em ( 1275 ,  176 ): (223, 192, 138)
# Valores RGB do pixel em ( 1275 ,  177 ): (223, 191, 140)
# Valores RGB do pixel em ( 1275 ,  178 ): (224, 192, 141)
# Valores RGB do pixel em ( 1275 ,  179 ): (225, 193, 142)
# Valores RGB do pixel em ( 1275 ,  180 ): (224, 192, 141)
# Valores RGB do pixel em ( 1275 ,  181 ): (221, 189, 138)
# Valores RGB do pixel em ( 1275 ,  182 ): (216, 184, 133)
# Valores RGB do pixel em ( 1275 ,  183 ): (212, 180, 129)
# Valores RGB do pixel em ( 1275 ,  184 ): (211, 179, 128)
# Valores RGB do pixel em ( 1275 ,  185 ): (213, 181, 130)
# Valores RGB do pixel em ( 1275 ,  186 ): (216, 184, 133)
# Valores RGB do pixel em ( 1275 ,  187 ): (219, 187, 136)
# Valores RGB do pixel em ( 1275 ,  188 ): (219, 187, 136)
# Valores RGB do pixel em ( 1275 ,  189 ): (218, 186, 135)
# Valores RGB do pixel em ( 1275 ,  190 ): (216, 184, 133)
# Valores RGB do pixel em ( 1275 ,  191 ): (214, 182, 131)
# Valores RGB do pixel em ( 1275 ,  192 ): (218, 187, 133)
# Valores RGB do pixel em ( 1275 ,  193 ): (219, 188, 133)
# Valores RGB do pixel em ( 1275 ,  194 ): (220, 189, 134)
# Valores RGB do pixel em ( 1275 ,  195 ): (220, 189, 135)
# Valores RGB do pixel em ( 1275 ,  196 ): (218, 187, 133)
# Valores RGB do pixel em ( 1275 ,  197 ): (218, 187, 133)
# Valores RGB do pixel em ( 1275 ,  198 ): (220, 187, 134)
# Valores RGB do pixel em ( 1275 ,  199 ): (221, 188, 137)
# Valores RGB do pixel em ( 1275 ,  200 ): (221, 188, 137)
# Valores RGB do pixel em ( 1275 ,  201 ): (220, 187, 136)
# Valores RGB do pixel em ( 1275 ,  202 ): (221, 185, 135)
# Valores RGB do pixel em ( 1275 ,  203 ): (219, 183, 135)
# Valores RGB do pixel em ( 1275 ,  204 ): (217, 181, 133)
# Valores RGB do pixel em ( 1275 ,  205 ): (216, 180, 132)
# Valores RGB do pixel em ( 1275 ,  206 ): (215, 179, 131)
# Valores RGB do pixel em ( 1275 ,  207 ): (214, 178, 130)
# Valores RGB do pixel em ( 1275 ,  208 ): (217, 179, 130)
# Valores RGB do pixel em ( 1275 ,  209 ): (217, 179, 130)
# Valores RGB do pixel em ( 1275 ,  210 ): (216, 178, 129)
# Valores RGB do pixel em ( 1275 ,  211 ): (214, 176, 127)
# Valores RGB do pixel em ( 1275 ,  212 ): (213, 175, 126)
# Valores RGB do pixel em ( 1275 ,  213 ): (212, 174, 125)
# Valores RGB do pixel em ( 1275 ,  214 ): (213, 175, 126)
# Valores RGB do pixel em ( 1275 ,  215 ): (213, 175, 126)
# Valores RGB do pixel em ( 1275 ,  216 ): (213, 176, 124)
# Valores RGB do pixel em ( 1275 ,  217 ): (213, 176, 124)
# Valores RGB do pixel em ( 1275 ,  218 ): (214, 177, 125)
# Valores RGB do pixel em ( 1275 ,  219 ): (216, 179, 127)
# Valores RGB do pixel em ( 1275 ,  220 ): (217, 180, 127)
# Valores RGB do pixel em ( 1275 ,  221 ): (218, 181, 128)
# Valores RGB do pixel em ( 1275 ,  222 ): (219, 182, 129)
# Valores RGB do pixel em ( 1275 ,  223 ): (220, 183, 131)
# Valores RGB do pixel em ( 1275 ,  224 ): (218, 182, 132)
# Valores RGB do pixel em ( 1275 ,  225 ): (219, 183, 133)
# Valores RGB do pixel em ( 1275 ,  226 ): (218, 182, 132)
# Valores RGB do pixel em ( 1275 ,  227 ): (216, 180, 130)
# Valores RGB do pixel em ( 1275 ,  228 ): (214, 178, 128)
# Valores RGB do pixel em ( 1275 ,  229 ): (212, 176, 126)
# Valores RGB do pixel em ( 1275 ,  230 ): (212, 176, 126)
# Valores RGB do pixel em ( 1275 ,  231 ): (213, 177, 127)
# Valores RGB do pixel em ( 1275 ,  232 ): (215, 179, 129)
# Valores RGB do pixel em ( 1275 ,  233 ): (216, 180, 130)
# Valores RGB do pixel em ( 1275 ,  234 ): (218, 182, 132)
# Valores RGB do pixel em ( 1275 ,  235 ): (219, 183, 133)
# Valores RGB do pixel em ( 1275 ,  236 ): (219, 183, 133)
# Valores RGB do pixel em ( 1275 ,  237 ): (217, 181, 131)
# Valores RGB do pixel em ( 1275 ,  238 ): (216, 180, 130)
# Valores RGB do pixel em ( 1275 ,  239 ): (214, 178, 128)
# Valores RGB do pixel em ( 1275 ,  240 ): (216, 179, 127)
# Valores RGB do pixel em ( 1275 ,  241 ): (217, 180, 128)
# Valores RGB do pixel em ( 1275 ,  242 ): (218, 181, 129)
# Valores RGB do pixel em ( 1275 ,  243 ): (219, 182, 130)
# Valores RGB do pixel em ( 1275 ,  244 ): (220, 183, 130)
# Valores RGB do pixel em ( 1275 ,  245 ): (220, 183, 130)
# Valores RGB do pixel em ( 1275 ,  246 ): (219, 182, 129)
# Valores RGB do pixel em ( 1275 ,  247 ): (219, 182, 129)
# Valores RGB do pixel em ( 1275 ,  248 ): (218, 181, 128)
# Valores RGB do pixel em ( 1275 ,  249 ): (220, 183, 130)
# Valores RGB do pixel em ( 1275 ,  250 ): (222, 185, 130)
# Valores RGB do pixel em ( 1275 ,  251 ): (224, 187, 132)
# Valores RGB do pixel em ( 1275 ,  252 ): (225, 188, 133)
# Valores RGB do pixel em ( 1275 ,  253 ): (224, 187, 132)
# Valores RGB do pixel em ( 1275 ,  254 ): (223, 186, 131)
# Valores RGB do pixel em ( 1275 ,  255 ): (222, 187, 131)
# Valores RGB do pixel em ( 1275 ,  256 ): (221, 188, 134)
# Valores RGB do pixel em ( 1275 ,  257 ): (218, 185, 131)
# Valores RGB do pixel em ( 1275 ,  258 ): (216, 183, 129)
# Valores RGB do pixel em ( 1275 ,  259 ): (214, 181, 127)
# Valores RGB do pixel em ( 1275 ,  260 ): (214, 181, 127)
# Valores RGB do pixel em ( 1275 ,  261 ): (215, 182, 128)
# Valores RGB do pixel em ( 1275 ,  262 ): (215, 182, 128)
# Valores RGB do pixel em ( 1275 ,  263 ): (215, 182, 128)
# Valores RGB do pixel em ( 1275 ,  264 ): (216, 183, 129)
# Valores RGB do pixel em ( 1275 ,  265 ): (214, 181, 127)
# Valores RGB do pixel em ( 1275 ,  266 ): (210, 177, 123)
# Valores RGB do pixel em ( 1275 ,  267 ): (208, 175, 121)
# Valores RGB do pixel em ( 1275 ,  268 ): (207, 174, 120)
# Valores RGB do pixel em ( 1275 ,  269 ): (209, 176, 122)
# Valores RGB do pixel em ( 1275 ,  270 ): (211, 178, 124)
# Valores RGB do pixel em ( 1275 ,  271 ): (212, 179, 125)
# Valores RGB do pixel em ( 1275 ,  272 ): (215, 179, 127)
# Valores RGB do pixel em ( 1275 ,  273 ): (214, 178, 128)
# Valores RGB do pixel em ( 1275 ,  274 ): (213, 177, 127)
# Valores RGB do pixel em ( 1275 ,  275 ): (212, 176, 126)
# Valores RGB do pixel em ( 1275 ,  276 ): (211, 175, 125)
# Valores RGB do pixel em ( 1275 ,  277 ): (211, 175, 125)
# Valores RGB do pixel em ( 1275 ,  278 ): (211, 175, 125)
# Valores RGB do pixel em ( 1275 ,  279 ): (211, 175, 125)
# Valores RGB do pixel em ( 1275 ,  280 ): (211, 175, 125)
# Valores RGB do pixel em ( 1275 ,  281 ): (211, 175, 125)
# Valores RGB do pixel em ( 1275 ,  282 ): (210, 174, 124)
# Valores RGB do pixel em ( 1275 ,  283 ): (209, 173, 123)
# Valores RGB do pixel em ( 1275 ,  284 ): (208, 172, 122)
# Valores RGB do pixel em ( 1275 ,  285 ): (206, 170, 120)
# Valores RGB do pixel em ( 1275 ,  286 ): (204, 168, 118)
# Valores RGB do pixel em ( 1275 ,  287 ): (203, 167, 117)
# Valores RGB do pixel em ( 1275 ,  288 ): (200, 166, 118)
# Valores RGB do pixel em ( 1275 ,  289 ): (200, 166, 118)
# Valores RGB do pixel em ( 1275 ,  290 ): (200, 166, 118)
# Valores RGB do pixel em ( 1275 ,  291 ): (201, 167, 119)
# Valores RGB do pixel em ( 1275 ,  292 ): (203, 170, 119)
# Valores RGB do pixel em ( 1275 ,  293 ): (203, 170, 119)
# Valores RGB do pixel em ( 1275 ,  294 ): (201, 168, 117)
# Valores RGB do pixel em ( 1275 ,  295 ): (199, 166, 115)
# Valores RGB do pixel em ( 1275 ,  296 ): (199, 166, 115)
# Valores RGB do pixel em ( 1275 ,  297 ): (199, 166, 115)
# Valores RGB do pixel em ( 1275 ,  298 ): (199, 166, 115)
# Valores RGB do pixel em ( 1275 ,  299 ): (198, 165, 112)
# Valores RGB do pixel em ( 1275 ,  300 ): (197, 164, 111)
# Valores RGB do pixel em ( 1275 ,  301 ): (196, 163, 110)
# Valores RGB do pixel em ( 1275 ,  302 ): (195, 162, 109)
# Valores RGB do pixel em ( 1275 ,  303 ): (194, 161, 110)
# Valores RGB do pixel em ( 1275 ,  304 ): (193, 159, 111)
# Valores RGB do pixel em ( 1275 ,  305 ): (193, 159, 113)
# Valores RGB do pixel em ( 1275 ,  306 ): (193, 159, 113)
# Valores RGB do pixel em ( 1275 ,  307 ): (192, 158, 112)
# Valores RGB do pixel em ( 1275 ,  308 ): (190, 156, 110)
# Valores RGB do pixel em ( 1275 ,  309 ): (188, 154, 108)
# Valores RGB do pixel em ( 1275 ,  310 ): (188, 154, 108)
# Valores RGB do pixel em ( 1275 ,  311 ): (189, 155, 109)
# Valores RGB do pixel em ( 1275 ,  312 ): (189, 155, 109)
# Valores RGB do pixel em ( 1275 ,  313 ): (188, 154, 108)
# Valores RGB do pixel em ( 1275 ,  314 ): (186, 152, 106)
# Valores RGB do pixel em ( 1275 ,  315 ): (186, 152, 106)
# Valores RGB do pixel em ( 1275 ,  316 ): (186, 152, 106)
# Valores RGB do pixel em ( 1275 ,  317 ): (186, 152, 106)
# Valores RGB do pixel em ( 1275 ,  318 ): (187, 153, 107)
# Valores RGB do pixel em ( 1275 ,  319 ): (187, 153, 107)
# Valores RGB do pixel em ( 1275 ,  320 ): (194, 155, 112)
# Valores RGB do pixel em ( 1275 ,  321 ): (192, 153, 110)
# Valores RGB do pixel em ( 1275 ,  322 ): (190, 153, 109)
# Valores RGB do pixel em ( 1275 ,  323 ): (188, 154, 109)
# Valores RGB do pixel em ( 1275 ,  324 ): (187, 154, 109)
# Valores RGB do pixel em ( 1275 ,  325 ): (186, 155, 109)
# Valores RGB do pixel em ( 1275 ,  326 ): (182, 154, 107)
# Valores RGB do pixel em ( 1275 ,  327 ): (180, 152, 105)
# Valores RGB do pixel em ( 1275 ,  328 ): (177, 150, 103)
# Valores RGB do pixel em ( 1275 ,  329 ): (177, 150, 103)
# Valores RGB do pixel em ( 1275 ,  330 ): (176, 149, 102)
# Valores RGB do pixel em ( 1275 ,  331 ): (175, 148, 101)
# Valores RGB do pixel em ( 1275 ,  332 ): (176, 148, 101)
# Valores RGB do pixel em ( 1275 ,  333 ): (179, 151, 104)
# Valores RGB do pixel em ( 1275 ,  334 ): (184, 153, 107)
# Valores RGB do pixel em ( 1275 ,  335 ): (187, 156, 110)
# Valores RGB do pixel em ( 1275 ,  336 ): (181, 153, 106)
# Valores RGB do pixel em ( 1275 ,  337 ): (179, 151, 104)
# Valores RGB do pixel em ( 1275 ,  338 ): (178, 150, 103)
# Valores RGB do pixel em ( 1275 ,  339 ): (179, 151, 104)
# Valores RGB do pixel em ( 1275 ,  340 ): (181, 153, 106)
# Valores RGB do pixel em ( 1275 ,  341 ): (182, 154, 107)
# Valores RGB do pixel em ( 1275 ,  342 ): (179, 150, 106)
# Valores RGB do pixel em ( 1275 ,  343 ): (177, 148, 104)
# Valores RGB do pixel em ( 1275 ,  344 ): (173, 144, 100)
# Valores RGB do pixel em ( 1275 ,  345 ): (173, 144, 100)
# Valores RGB do pixel em ( 1275 ,  346 ): (175, 146, 102)
# Valores RGB do pixel em ( 1275 ,  347 ): (179, 150, 106)
# Valores RGB do pixel em ( 1275 ,  348 ): (182, 153, 111)
# Valores RGB do pixel em ( 1275 ,  349 ): (182, 153, 111)
# Valores RGB do pixel em ( 1275 ,  350 ): (179, 150, 108)
# Valores RGB do pixel em ( 1275 ,  351 ): (175, 146, 104)
# Valores RGB do pixel em ( 1275 ,  352 ): (170, 143, 100)
# Valores RGB do pixel em ( 1275 ,  353 ): (169, 142, 99)
# Valores RGB do pixel em ( 1275 ,  354 ): (167, 140, 97)
# Valores RGB do pixel em ( 1275 ,  355 ): (166, 139, 96)
# Valores RGB do pixel em ( 1275 ,  356 ): (168, 141, 98)
# Valores RGB do pixel em ( 1275 ,  357 ): (172, 145, 102)
# Valores RGB do pixel em ( 1275 ,  358 ): (178, 151, 108)
# Valores RGB do pixel em ( 1275 ,  359 ): (182, 155, 112)
# Valores RGB do pixel em ( 1275 ,  360 ): (186, 159, 116)
# Valores RGB do pixel em ( 1275 ,  361 ): (183, 156, 113)
# Valores RGB do pixel em ( 1275 ,  362 ): (180, 153, 110)
# Valores RGB do pixel em ( 1275 ,  363 ): (177, 150, 107)
# Valores RGB do pixel em ( 1275 ,  364 ): (175, 148, 105)
# Valores RGB do pixel em ( 1275 ,  365 ): (173, 146, 103)
# Valores RGB do pixel em ( 1275 ,  366 ): (171, 144, 101)
# Valores RGB do pixel em ( 1275 ,  367 ): (170, 141, 101)
# Valores RGB do pixel em ( 1275 ,  368 ): (167, 134, 101)
# Valores RGB do pixel em ( 1275 ,  369 ): (168, 133, 101)
# Valores RGB do pixel em ( 1275 ,  370 ): (168, 133, 101)
# Valores RGB do pixel em ( 1275 ,  371 ): (169, 135, 100)
# Valores RGB do pixel em ( 1275 ,  372 ): (172, 138, 103)
# Valores RGB do pixel em ( 1275 ,  373 ): (176, 144, 106)
# Valores RGB do pixel em ( 1275 ,  374 ): (180, 148, 110)
# Valores RGB do pixel em ( 1275 ,  375 ): (183, 151, 112)
# Valores RGB do pixel em ( 1275 ,  376 ): (185, 153, 114)
# Valores RGB do pixel em ( 1275 ,  377 ): (185, 153, 114)
# Valores RGB do pixel em ( 1275 ,  378 ): (186, 154, 116)
# Valores RGB do pixel em ( 1275 ,  379 ): (184, 154, 118)
# Valores RGB do pixel em ( 1275 ,  380 ): (182, 152, 116)
# Valores RGB do pixel em ( 1275 ,  381 ): (179, 149, 115)
# Valores RGB do pixel em ( 1275 ,  382 ): (175, 145, 111)
# Valores RGB do pixel em ( 1275 ,  383 ): (170, 144, 109)
# Valores RGB do pixel em ( 1275 ,  384 ): (164, 142, 105)
# Valores RGB do pixel em ( 1275 ,  385 ): (161, 141, 104)
# Valores RGB do pixel em ( 1275 ,  386 ): (160, 140, 103)
# Valores RGB do pixel em ( 1275 ,  387 ): (160, 140, 103)
# Valores RGB do pixel em ( 1275 ,  388 ): (163, 141, 104)
# Valores RGB do pixel em ( 1275 ,  389 ): (164, 142, 105)
# Valores RGB do pixel em ( 1275 ,  390 ): (165, 143, 106)
# Valores RGB do pixel em ( 1275 ,  391 ): (165, 143, 106)
# Valores RGB do pixel em ( 1275 ,  392 ): (165, 141, 105)
# Valores RGB do pixel em ( 1275 ,  393 ): (163, 139, 103)
# Valores RGB do pixel em ( 1275 ,  394 ): (162, 138, 102)
# Valores RGB do pixel em ( 1275 ,  395 ): (162, 138, 102)
# Valores RGB do pixel em ( 1275 ,  396 ): (163, 139, 103)
# Valores RGB do pixel em ( 1275 ,  397 ): (165, 141, 105)
# Valores RGB do pixel em ( 1275 ,  398 ): (165, 141, 105)
# Valores RGB do pixel em ( 1275 ,  399 ): (166, 140, 103)
# Valores RGB do pixel em ( 1275 ,  400 ): (174, 146, 106)
# Valores RGB do pixel em ( 1275 ,  401 ): (173, 146, 103)
# Valores RGB do pixel em ( 1275 ,  402 ): (173, 146, 103)
# Valores RGB do pixel em ( 1275 ,  403 ): (175, 148, 105)
# Valores RGB do pixel em ( 1275 ,  404 ): (177, 153, 109)
# Valores RGB do pixel em ( 1275 ,  405 ): (180, 156, 112)
# Valores RGB do pixel em ( 1275 ,  406 ): (181, 157, 113)
# Valores RGB do pixel em ( 1275 ,  407 ): (181, 157, 113)
# Valores RGB do pixel em ( 1275 ,  408 ): (178, 154, 110)
# Valores RGB do pixel em ( 1275 ,  409 ): (177, 153, 109)
# Valores RGB do pixel em ( 1275 ,  410 ): (175, 152, 110)
# Valores RGB do pixel em ( 1275 ,  411 ): (174, 151, 109)
# Valores RGB do pixel em ( 1275 ,  412 ): (174, 151, 109)
# Valores RGB do pixel em ( 1275 ,  413 ): (174, 151, 109)
# Valores RGB do pixel em ( 1275 ,  414 ): (174, 151, 109)
# Valores RGB do pixel em ( 1275 ,  415 ): (176, 152, 108)
# Valores RGB do pixel em ( 1275 ,  416 ): (174, 147, 102)
# Valores RGB do pixel em ( 1275 ,  417 ): (176, 148, 101)
# Valores RGB do pixel em ( 1275 ,  418 ): (178, 150, 103)
# Valores RGB do pixel em ( 1275 ,  419 ): (180, 152, 105)
# Valores RGB do pixel em ( 1275 ,  420 ): (180, 151, 107)
# Valores RGB do pixel em ( 1275 ,  421 ): (179, 150, 106)
# Valores RGB do pixel em ( 1275 ,  422 ): (178, 149, 105)
# Valores RGB do pixel em ( 1275 ,  423 ): (177, 148, 104)
# Valores RGB do pixel em ( 1275 ,  424 ): (171, 142, 100)
# Valores RGB do pixel em ( 1275 ,  425 ): (170, 141, 99)
# Valores RGB do pixel em ( 1275 ,  426 ): (170, 141, 99)
# Valores RGB do pixel em ( 1275 ,  427 ): (173, 144, 102)
# Valores RGB do pixel em ( 1275 ,  428 ): (177, 148, 106)
# Valores RGB do pixel em ( 1275 ,  429 ): (177, 148, 106)
# Valores RGB do pixel em ( 1275 ,  430 ): (173, 144, 104)
# Valores RGB do pixel em ( 1275 ,  431 ): (167, 139, 99)
# Valores RGB do pixel em ( 1275 ,  432 ): (165, 144, 101)
# Valores RGB do pixel em ( 1275 ,  433 ): (160, 143, 97)
# Valores RGB do pixel em ( 1275 ,  434 ): (155, 138, 92)
# Valores RGB do pixel em ( 1275 ,  435 ): (145, 128, 84)
# Valores RGB do pixel em ( 1275 ,  436 ): (133, 116, 72)
# Valores RGB do pixel em ( 1275 ,  437 ): (126, 109, 65)
# Valores RGB do pixel em ( 1275 ,  438 ): (128, 111, 67)
# Valores RGB do pixel em ( 1275 ,  439 ): (134, 117, 73)
# Valores RGB do pixel em ( 1275 ,  440 ): (146, 129, 85)
# Valores RGB do pixel em ( 1275 ,  441 ): (150, 133, 89)
# Valores RGB do pixel em ( 1275 ,  442 ): (156, 139, 96)
# Valores RGB do pixel em ( 1275 ,  443 ): (163, 146, 103)
# Valores RGB do pixel em ( 1275 ,  444 ): (168, 151, 108)
# Valores RGB do pixel em ( 1275 ,  445 ): (172, 155, 111)
# Valores RGB do pixel em ( 1275 ,  446 ): (175, 158, 114)
# Valores RGB do pixel em ( 1275 ,  447 ): (178, 159, 117)
# Valores RGB do pixel em ( 1275 ,  448 ): (194, 168, 131)
# Valores RGB do pixel em ( 1275 ,  449 ): (198, 169, 135)
# Valores RGB do pixel em ( 1275 ,  450 ): (200, 171, 137)
# Valores RGB do pixel em ( 1275 ,  451 ): (201, 172, 138)
# Valores RGB do pixel em ( 1275 ,  452 ): (200, 174, 139)
# Valores RGB do pixel em ( 1275 ,  453 ): (201, 175, 140)
# Valores RGB do pixel em ( 1275 ,  454 ): (202, 176, 141)
# Valores RGB do pixel em ( 1275 ,  455 ): (202, 176, 141)
# Valores RGB do pixel em ( 1275 ,  456 ): (199, 175, 139)
# Valores RGB do pixel em ( 1275 ,  457 ): (195, 171, 135)
# Valores RGB do pixel em ( 1275 ,  458 ): (189, 165, 129)
# Valores RGB do pixel em ( 1275 ,  459 ): (187, 163, 127)
# Valores RGB do pixel em ( 1275 ,  460 ): (187, 163, 127)
# Valores RGB do pixel em ( 1275 ,  461 ): (186, 162, 126)
# Valores RGB do pixel em ( 1275 ,  462 ): (180, 158, 121)
# Valores RGB do pixel em ( 1275 ,  463 ): (176, 154, 115)
# Valores RGB do pixel em ( 1275 ,  464 ): (172, 150, 109)
# Valores RGB do pixel em ( 1275 ,  465 ): (170, 149, 106)
# Valores RGB do pixel em ( 1275 ,  466 ): (164, 145, 102)
# Valores RGB do pixel em ( 1275 ,  467 ): (160, 141, 98)
# Valores RGB do pixel em ( 1275 ,  468 ): (157, 138, 95)
# Valores RGB do pixel em ( 1275 ,  469 ): (156, 137, 94)
# Valores RGB do pixel em ( 1275 ,  470 ): (155, 138, 95)
# Valores RGB do pixel em ( 1275 ,  471 ): (155, 138, 95)
# Valores RGB do pixel em ( 1275 ,  472 ): (157, 140, 97)
# Valores RGB do pixel em ( 1275 ,  473 ): (157, 142, 99)
# Valores RGB do pixel em ( 1275 ,  474 ): (159, 144, 103)
# Valores RGB do pixel em ( 1275 ,  475 ): (158, 143, 102)
# Valores RGB do pixel em ( 1275 ,  476 ): (155, 140, 99)
# Valores RGB do pixel em ( 1275 ,  477 ): (151, 138, 96)
# Valores RGB do pixel em ( 1275 ,  478 ): (150, 137, 95)
# Valores RGB do pixel em ( 1275 ,  479 ): (151, 136, 95)
# Valores RGB do pixel em ( 1275 ,  480 ): (150, 132, 92)
# Valores RGB do pixel em ( 1275 ,  481 ): (157, 138, 96)
# Valores RGB do pixel em ( 1275 ,  482 ): (161, 142, 100)
# Valores RGB do pixel em ( 1275 ,  483 ): (160, 141, 101)
# Valores RGB do pixel em ( 1275 ,  484 ): (158, 140, 100)
# Valores RGB do pixel em ( 1275 ,  485 ): (157, 139, 99)
# Valores RGB do pixel em ( 1275 ,  486 ): (154, 136, 96)
# Valores RGB do pixel em ( 1275 ,  487 ): (152, 134, 96)
# Valores RGB do pixel em ( 1275 ,  488 ): (151, 136, 97)
# Valores RGB do pixel em ( 1275 ,  489 ): (148, 133, 94)
# Valores RGB do pixel em ( 1275 ,  490 ): (141, 126, 87)
# Valores RGB do pixel em ( 1275 ,  491 ): (132, 117, 78)
# Valores RGB do pixel em ( 1275 ,  492 ): (124, 109, 70)
# Valores RGB do pixel em ( 1275 ,  493 ): (123, 108, 69)
# Valores RGB do pixel em ( 1275 ,  494 ): (128, 114, 75)
# Valores RGB do pixel em ( 1275 ,  495 ): (135, 120, 81)
# Valores RGB do pixel em ( 1275 ,  496 ): (140, 120, 83)
# Valores RGB do pixel em ( 1275 ,  497 ): (140, 118, 81)
# Valores RGB do pixel em ( 1275 ,  498 ): (136, 116, 79)
# Valores RGB do pixel em ( 1275 ,  499 ): (135, 115, 78)
# Valores RGB do pixel em ( 1275 ,  500 ): (136, 118, 80)
# Valores RGB do pixel em ( 1275 ,  501 ): (137, 122, 81)
# Valores RGB do pixel em ( 1275 ,  502 ): (140, 127, 83)
# Valores RGB do pixel em ( 1275 ,  503 ): (143, 130, 85)
# Valores RGB do pixel em ( 1275 ,  504 ): (155, 142, 97)
# Valores RGB do pixel em ( 1275 ,  505 ): (177, 165, 117)
# Valores RGB do pixel em ( 1275 ,  506 ): (183, 171, 123)
# Valores RGB do pixel em ( 1275 ,  507 ): (154, 142, 92)
# Valores RGB do pixel em ( 1275 ,  508 ): (140, 127, 75)
# Valores RGB do pixel em ( 1275 ,  509 ): (173, 157, 106)
# Valores RGB do pixel em ( 1275 ,  510 ): (193, 177, 125)
# Valores RGB do pixel em ( 1275 ,  511 ): (171, 158, 106)
# Valores RGB do pixel em ( 1275 ,  512 ): (147, 140, 88)
# Valores RGB do pixel em ( 1275 ,  513 ): (155, 149, 97)
# Valores RGB do pixel em ( 1275 ,  514 ): (171, 165, 115)
# Valores RGB do pixel em ( 1275 ,  515 ): (154, 148, 100)
# Valores RGB do pixel em ( 1275 ,  516 ): (132, 125, 79)
# Valores RGB do pixel em ( 1275 ,  517 ): (129, 122, 80)
# Valores RGB do pixel em ( 1275 ,  518 ): (120, 112, 75)
# Valores RGB do pixel em ( 1275 ,  519 ): (116, 107, 74)
# Valores RGB do pixel em ( 1275 ,  520 ): (117, 108, 79)
# Valores RGB do pixel em ( 1275 ,  521 ): (114, 102, 76)
# Valores RGB do pixel em ( 1275 ,  522 ): (107, 95, 73)
# Valores RGB do pixel em ( 1275 ,  523 ): (96, 83, 66)
# Valores RGB do pixel em ( 1275 ,  524 ): (88, 75, 59)
# Valores RGB do pixel em ( 1275 ,  525 ): (87, 73, 62)
# Valores RGB do pixel em ( 1275 ,  526 ): (92, 78, 69)
# Valores RGB do pixel em ( 1275 ,  527 ): (99, 85, 74)
# Valores RGB do pixel em ( 1275 ,  528 ): (108, 92, 79)
# Valores RGB do pixel em ( 1275 ,  529 ): (112, 96, 80)
# Valores RGB do pixel em ( 1275 ,  530 ): (115, 99, 83)
# Valores RGB do pixel em ( 1275 ,  531 ): (115, 100, 81)
# Valores RGB do pixel em ( 1275 ,  532 ): (114, 97, 79)
# Valores RGB do pixel em ( 1275 ,  533 ): (111, 94, 74)
# Valores RGB do pixel em ( 1275 ,  534 ): (105, 88, 68)
# Valores RGB do pixel em ( 1275 ,  535 ): (101, 85, 62)
# Valores RGB do pixel em ( 1275 ,  536 ): (96, 78, 56)
# Valores RGB do pixel em ( 1275 ,  537 ): (92, 74, 54)
# Valores RGB do pixel em ( 1275 ,  538 ): (86, 68, 48)
# Valores RGB do pixel em ( 1275 ,  539 ): (82, 63, 46)
# Valores RGB do pixel em ( 1275 ,  540 ): (81, 62, 45)
# Valores RGB do pixel em ( 1275 ,  541 ): (81, 62, 47)
# Valores RGB do pixel em ( 1275 ,  542 ): (85, 63, 49)
# Valores RGB do pixel em ( 1275 ,  543 ): (87, 64, 50)
# Valores RGB do pixel em ( 1275 ,  544 ): (90, 65, 45)
# Valores RGB do pixel em ( 1275 ,  545 ): (94, 67, 46)
# Valores RGB do pixel em ( 1275 ,  546 ): (95, 70, 48)
# Valores RGB do pixel em ( 1275 ,  547 ): (95, 70, 48)
# Valores RGB do pixel em ( 1275 ,  548 ): (92, 70, 47)
# Valores RGB do pixel em ( 1275 ,  549 ): (90, 72, 48)
# Valores RGB do pixel em ( 1275 ,  550 ): (90, 74, 49)
# Valores RGB do pixel em ( 1275 ,  551 ): (91, 75, 49)
# Valores RGB do pixel em ( 1275 ,  552 ): (85, 71, 44)
# Valores RGB do pixel em ( 1275 ,  553 ): (84, 70, 43)
# Valores RGB do pixel em ( 1275 ,  554 ): (83, 69, 42)
# Valores RGB do pixel em ( 1275 ,  555 ): (84, 70, 43)
# Valores RGB do pixel em ( 1275 ,  556 ): (86, 70, 44)
# Valores RGB do pixel em ( 1275 ,  557 ): (85, 69, 43)
# Valores RGB do pixel em ( 1275 ,  558 ): (82, 66, 40)
# Valores RGB do pixel em ( 1275 ,  559 ): (78, 64, 38)
# Valores RGB do pixel em ( 1275 ,  560 ): (71, 60, 40)
# Valores RGB do pixel em ( 1275 ,  561 ): (66, 59, 40)
# Valores RGB do pixel em ( 1275 ,  562 ): (63, 56, 38)
# Valores RGB do pixel em ( 1275 ,  563 ): (58, 50, 37)
# Valores RGB do pixel em ( 1275 ,  564 ): (54, 45, 36)
# Valores RGB do pixel em ( 1275 ,  565 ): (52, 43, 36)
# Valores RGB do pixel em ( 1275 ,  566 ): (51, 43, 40)
# Valores RGB do pixel em ( 1275 ,  567 ): (52, 44, 42)
# Valores RGB do pixel em ( 1275 ,  568 ): (47, 38, 39)
# Valores RGB do pixel em ( 1275 ,  569 ): (46, 37, 38)
# Valores RGB do pixel em ( 1275 ,  570 ): (46, 37, 38)
# Valores RGB do pixel em ( 1275 ,  571 ): (46, 38, 36)
# Valores RGB do pixel em ( 1275 ,  572 ): (46, 38, 36)
# Valores RGB do pixel em ( 1275 ,  573 ): (46, 38, 35)
# Valores RGB do pixel em ( 1275 ,  574 ): (46, 39, 33)
# Valores RGB do pixel em ( 1275 ,  575 ): (44, 40, 31)
# Valores RGB do pixel em ( 1275 ,  576 ): (44, 44, 32)
# Valores RGB do pixel em ( 1275 ,  577 ): (60, 61, 47)
# Valores RGB do pixel em ( 1275 ,  578 ): (75, 76, 62)
# Valores RGB do pixel em ( 1275 ,  579 ): (82, 83, 69)
# Valores RGB do pixel em ( 1275 ,  580 ): (66, 67, 53)
# Valores RGB do pixel em ( 1275 ,  581 ): (61, 62, 48)
# Valores RGB do pixel em ( 1275 ,  582 ): (68, 69, 55)
# Valores RGB do pixel em ( 1275 ,  583 ): (47, 48, 34)
# Valores RGB do pixel em ( 1275 ,  584 ): (43, 44, 30)
# Valores RGB do pixel em ( 1275 ,  585 ): (42, 43, 29)
# Valores RGB do pixel em ( 1275 ,  586 ): (39, 39, 27)
# Valores RGB do pixel em ( 1275 ,  587 ): (37, 37, 25)
# Valores RGB do pixel em ( 1275 ,  588 ): (35, 35, 23)
# Valores RGB do pixel em ( 1275 ,  589 ): (34, 34, 22)
# Valores RGB do pixel em ( 1275 ,  590 ): (34, 34, 22)
# Valores RGB do pixel em ( 1275 ,  591 ): (33, 35, 24)
# Valores RGB do pixel em ( 1275 ,  592 ): (24, 29, 22)
# Valores RGB do pixel em ( 1275 ,  593 ): (27, 34, 27)
# Valores RGB do pixel em ( 1275 ,  594 ): (27, 38, 32)
# Valores RGB do pixel em ( 1275 ,  595 ): (29, 40, 36)
# Valores RGB do pixel em ( 1275 ,  596 ): (29, 39, 38)
# Valores RGB do pixel em ( 1275 ,  597 ): (29, 33, 32)
# Valores RGB do pixel em ( 1275 ,  598 ): (33, 27, 27)
# Valores RGB do pixel em ( 1275 ,  599 ): (41, 26, 23)
# Valores RGB do pixel em ( 1275 ,  600 ): (54, 26, 22)
# Valores RGB do pixel em ( 1275 ,  601 ): (115, 81, 72)
# Valores RGB do pixel em ( 1275 ,  602 ): (160, 124, 112)
# Valores RGB do pixel em ( 1275 ,  603 ): (152, 120, 107)
# Valores RGB do pixel em ( 1275 ,  604 ): (92, 69, 55)
# Valores RGB do pixel em ( 1275 ,  605 ): (41, 28, 12)
# Valores RGB do pixel em ( 1275 ,  606 ): (36, 33, 16)
# Valores RGB do pixel em ( 1275 ,  607 ): (32, 32, 20)
# Valores RGB do pixel em ( 1275 ,  608 ): (29, 28, 24)
# Valores RGB do pixel em ( 1275 ,  609 ): (32, 31, 29)
# Valores RGB do pixel em ( 1275 ,  610 ): (37, 36, 34)
# Valores RGB do pixel em ( 1275 ,  611 ): (42, 41, 37)
# Valores RGB do pixel em ( 1275 ,  612 ): (45, 44, 40)
# Valores RGB do pixel em ( 1275 ,  613 ): (45, 44, 39)
# Valores RGB do pixel em ( 1275 ,  614 ): (44, 45, 37)
# Valores RGB do pixel em ( 1275 ,  615 ): (43, 45, 34)
# Valores RGB do pixel em ( 1275 ,  616 ): (44, 46, 35)
# Valores RGB do pixel em ( 1275 ,  617 ): (42, 44, 33)
# Valores RGB do pixel em ( 1275 ,  618 ): (37, 40, 29)
# Valores RGB do pixel em ( 1275 ,  619 ): (33, 36, 27)
# Valores RGB do pixel em ( 1275 ,  620 ): (36, 39, 30)
# Valores RGB do pixel em ( 1275 ,  621 ): (40, 43, 34)
# Valores RGB do pixel em ( 1275 ,  622 ): (39, 42, 35)
# Valores RGB do pixel em ( 1275 ,  623 ): (35, 38, 31)
# Valores RGB do pixel em ( 1275 ,  624 ): (31, 33, 28)
# Valores RGB do pixel em ( 1275 ,  625 ): (30, 32, 27)
# Valores RGB do pixel em ( 1275 ,  626 ): (27, 29, 26)
# Valores RGB do pixel em ( 1275 ,  627 ): (26, 31, 27)
# Valores RGB do pixel em ( 1275 ,  628 ): (30, 35, 31)
# Valores RGB do pixel em ( 1275 ,  629 ): (35, 37, 34)
# Valores RGB do pixel em ( 1275 ,  630 ): (49, 50, 45)
# Valores RGB do pixel em ( 1275 ,  631 ): (69, 68, 63)
# Valores RGB do pixel em ( 1275 ,  632 ): (119, 114, 108)
# Valores RGB do pixel em ( 1275 ,  633 ): (94, 84, 74)
# Valores RGB do pixel em ( 1275 ,  634 ): (48, 35, 19)
# Valores RGB do pixel em ( 1275 ,  635 ): (89, 71, 51)
# Valores RGB do pixel em ( 1275 ,  636 ): (134, 110, 86)
# Valores RGB do pixel em ( 1275 ,  637 ): (137, 110, 83)
# Valores RGB do pixel em ( 1275 ,  638 ): (170, 141, 111)
# Valores RGB do pixel em ( 1275 ,  639 ): (177, 147, 111)
# Valores RGB do pixel em ( 1275 ,  640 ): (163, 136, 89)
# Valores RGB do pixel em ( 1275 ,  641 ): (201, 175, 126)
# Valores RGB do pixel em ( 1275 ,  642 ): (195, 168, 123)
# Valores RGB do pixel em ( 1275 ,  643 ): (219, 190, 148)
# Valores RGB do pixel em ( 1275 ,  644 ): (226, 194, 155)
# Valores RGB do pixel em ( 1275 ,  645 ): (222, 190, 151)
# Valores RGB do pixel em ( 1275 ,  646 ): (237, 204, 161)
# Valores RGB do pixel em ( 1275 ,  647 ): (218, 184, 138)
# Valores RGB do pixel em ( 1275 ,  648 ): (225, 192, 139)
# Valores RGB do pixel em ( 1275 ,  649 ): (220, 188, 131)
# Valores RGB do pixel em ( 1275 ,  650 ): (188, 156, 97)
# Valores RGB do pixel em ( 1275 ,  651 ): (177, 145, 84)
# Valores RGB do pixel em ( 1275 ,  652 ): (175, 143, 84)
# Valores RGB do pixel em ( 1275 ,  653 ): (159, 126, 72)
# Valores RGB do pixel em ( 1275 ,  654 ): (154, 121, 70)
# Valores RGB do pixel em ( 1275 ,  655 ): (152, 121, 74)
# ...
# Valores RGB do pixel em ( 1279 ,  669 ): (120, 104, 70)
# Valores RGB do pixel em ( 1279 ,  670 ): (116, 101, 68)
# Valores RGB do pixel em ( 1279 ,  671 ): (111, 93, 69)
# Valores RGB do pixel em ( 1279 ,  672 ): (159, 136, 128)
# Valores RGB do pixel em ( 1279 ,  673 ): (157, 129, 125)
# Valores RGB do pixel em ( 1279 ,  674 ): (154, 126, 115)
# Valores RGB do pixel em ( 1279 ,  675 ): (168, 137, 119)
# Valores RGB do pixel em ( 1279 ,  676 ): (187, 155, 132)
# Valores RGB do pixel em ( 1279 ,  677 ): (181, 150, 121)
# Valores RGB do pixel em ( 1279 ,  678 ): (163, 134, 102)
# Valores RGB do pixel em ( 1279 ,  679 ): (159, 135, 101)
# Valores RGB do pixel em ( 1279 ,  680 ): (135, 116, 84)
# Valores RGB do pixel em ( 1279 ,  681 ): (152, 137, 108)
# Valores RGB do pixel em ( 1279 ,  682 ): (138, 128, 101)
# Valores RGB do pixel em ( 1279 ,  683 ): (125, 118, 92)
# Valores RGB do pixel em ( 1279 ,  684 ): (115, 107, 84)
# Valores RGB do pixel em ( 1279 ,  685 ): (110, 102, 79)
# Valores RGB do pixel em ( 1279 ,  686 ): (124, 113, 91)
# Valores RGB do pixel em ( 1279 ,  687 ): (126, 111, 92)
# Valores RGB do pixel em ( 1279 ,  688 ): (123, 105, 91)
# Valores RGB do pixel em ( 1279 ,  689 ): (120, 102, 92)
# Valores RGB do pixel em ( 1279 ,  690 ): (117, 100, 92)
# Valores RGB do pixel em ( 1279 ,  691 ): (106, 91, 86)
# Valores RGB do pixel em ( 1279 ,  692 ): (95, 81, 78)
# Valores RGB do pixel em ( 1279 ,  693 ): (93, 81, 81)
# Valores RGB do pixel em ( 1279 ,  694 ): (84, 74, 75)
# Valores RGB do pixel em ( 1279 ,  695 ): (63, 54, 57)
# Valores RGB do pixel em ( 1279 ,  696 ): (44, 38, 42)
# Valores RGB do pixel em ( 1279 ,  697 ): (66, 60, 64)
# Valores RGB do pixel em ( 1279 ,  698 ): (57, 52, 56)
# Valores RGB do pixel em ( 1279 ,  699 ): (74, 70, 71)
# Valores RGB do pixel em ( 1279 ,  700 ): (59, 55, 54)
# Valores RGB do pixel em ( 1279 ,  701 ): (68, 64, 61)
# Valores RGB do pixel em ( 1279 ,  702 ): (76, 73, 68)
# Valores RGB do pixel em ( 1279 ,  703 ): (55, 52, 47)
# Valores RGB do pixel em ( 1279 ,  704 ): (36, 35, 31)
# Valores RGB do pixel em ( 1279 ,  705 ): (31, 30, 26)
# Valores RGB do pixel em ( 1279 ,  706 ): (57, 57, 55)
# Valores RGB do pixel em ( 1279 ,  707 ): (68, 70, 67)
# Valores RGB do pixel em ( 1279 ,  708 ): (36, 40, 39)
# Valores RGB do pixel em ( 1279 ,  709 ): (34, 38, 39)
# Valores RGB do pixel em ( 1279 ,  710 ): (58, 62, 65)
# Valores RGB do pixel em ( 1279 ,  711 ): (51, 54, 59)
# Valores RGB do pixel em ( 1279 ,  712 ): (67, 70, 77)
# Valores RGB do pixel em ( 1279 ,  713 ): (40, 43, 50)
# Valores RGB do pixel em ( 1279 ,  714 ): (61, 61, 69)
# Valores RGB do pixel em ( 1279 ,  715 ): (47, 47, 55)
# Valores RGB do pixel em ( 1279 ,  716 ): (43, 42, 48)
# Valores RGB do pixel em ( 1279 ,  717 ): (66, 65, 71)
# Valores RGB do pixel em ( 1279 ,  718 ): (50, 47, 54)
# Valores RGB do pixel em ( 1279 ,  719 ): (41, 35, 37)
# Valores RGB do pixel em ( 1279 ,  720 ): (97, 82, 75)
# Valores RGB do pixel em ( 1279 ,  721 ): (143, 126, 116)
# Valores RGB do pixel em ( 1279 ,  722 ): (57, 42, 37)
# Valores RGB do pixel em ( 1279 ,  723 ): (41, 25, 25)
# Valores RGB do pixel em ( 1279 ,  724 ): (65, 49, 50)
# Valores RGB do pixel em ( 1279 ,  725 ): (94, 76, 72)
# Valores RGB do pixel em ( 1279 ,  726 ): (162, 144, 130)
# Valores RGB do pixel em ( 1279 ,  727 ): (125, 105, 81)
# Valores RGB do pixel em ( 1279 ,  728 ): (134, 111, 77)
# Valores RGB do pixel em ( 1279 ,  729 ): (141, 118, 76)
# Valores RGB do pixel em ( 1279 ,  730 ): (121, 97, 53)
# Valores RGB do pixel em ( 1279 ,  731 ): (142, 118, 80)
# Valores RGB do pixel em ( 1279 ,  732 ): (100, 79, 52)
# Valores RGB do pixel em ( 1279 ,  733 ): (59, 40, 25)
# Valores RGB do pixel em ( 1279 ,  734 ): (115, 100, 97)
# Valores RGB do pixel em ( 1279 ,  735 ): (124, 110, 99)
# Valores RGB do pixel em ( 1279 ,  736 ): (153, 141, 99)
# Valores RGB do pixel em ( 1279 ,  737 ): (146, 134, 82)
# Valores RGB do pixel em ( 1279 ,  738 ): (95, 82, 40)
# Valores RGB do pixel em ( 1279 ,  739 ): (36, 21, 0)
# Valores RGB do pixel em ( 1279 ,  740 ): (65, 49, 34)
# Valores RGB do pixel em ( 1279 ,  741 ): (62, 44, 40)
# Valores RGB do pixel em ( 1279 ,  742 ): (65, 49, 50)
# Valores RGB do pixel em ( 1279 ,  743 ): (118, 102, 105)
# Valores RGB do pixel em ( 1279 ,  744 ): (77, 63, 63)
# Valores RGB do pixel em ( 1279 ,  745 ): (57, 43, 40)
# Valores RGB do pixel em ( 1279 ,  746 ): (48, 34, 25)
# Valores RGB do pixel em ( 1279 ,  747 ): (69, 56, 40)
# Valores RGB do pixel em ( 1279 ,  748 ): (59, 47, 25)
# Valores RGB do pixel em ( 1279 ,  749 ): (144, 132, 106)
# Valores RGB do pixel em ( 1279 ,  750 ): (132, 118, 91)
# Valores RGB do pixel em ( 1279 ,  751 ): (42, 25, 0)
# Valores RGB do pixel em ( 1279 ,  752 ): (114, 90, 66)
# Valores RGB do pixel em ( 1279 ,  753 ): (137, 109, 87)
# Valores RGB do pixel em ( 1279 ,  754 ): (155, 129, 104)
# Valores RGB do pixel em ( 1279 ,  755 ): (151, 125, 98)
# Valores RGB do pixel em ( 1279 ,  756 ): (134, 111, 80)
# Valores RGB do pixel em ( 1279 ,  757 ): (112, 91, 62)
# Valores RGB do pixel em ( 1279 ,  758 ): (94, 74, 47)
# Valores RGB do pixel em ( 1279 ,  759 ): (115, 97, 75)
# Valores RGB do pixel em ( 1279 ,  760 ): (102, 86, 70)
# Valores RGB do pixel em ( 1279 ,  761 ): (48, 36, 24)
# Valores RGB do pixel em ( 1279 ,  762 ): (34, 25, 18)
# Valores RGB do pixel em ( 1279 ,  763 ): (34, 29, 23)
# Valores RGB do pixel em ( 1279 ,  764 ): (71, 70, 65)
# Valores RGB do pixel em ( 1279 ,  765 ): (98, 101, 92)
# Valores RGB do pixel em ( 1279 ,  766 ): (52, 58, 46)
# Valores RGB do pixel em ( 1279 ,  767 ): (31, 37, 27)
# Valores RGB do pixel em ( 1279 ,  768 ): (36, 36, 34)
# Valores RGB do pixel em ( 1279 ,  769 ): (24, 24, 24)
# Valores RGB do pixel em ( 1279 ,  770 ): (35, 37, 36)
# Valores RGB do pixel em ( 1279 ,  771 ): (31, 33, 32)
# Valores RGB do pixel em ( 1279 ,  772 ): (39, 39, 37)
# Valores RGB do pixel em ( 1279 ,  773 ): (60, 59, 55)
# Valores RGB do pixel em ( 1279 ,  774 ): (77, 69, 66)
# Valores RGB do pixel em ( 1279 ,  775 ): (122, 108, 105)
# Valores RGB do pixel em ( 1279 ,  776 ): (102, 82, 75)
# Valores RGB do pixel em ( 1279 ,  777 ): (62, 35, 24)
# Valores RGB do pixel em ( 1279 ,  778 ): (76, 44, 29)
# Valores RGB do pixel em ( 1279 ,  779 ): (81, 46, 24)
# Valores RGB do pixel em ( 1279 ,  780 ): (190, 156, 128)
# Valores RGB do pixel em ( 1279 ,  781 ): (205, 175, 141)
# Valores RGB do pixel em ( 1279 ,  782 ): (99, 71, 32)
# Valores RGB do pixel em ( 1279 ,  783 ): (127, 98, 64)
# Valores RGB do pixel em ( 1279 ,  784 ): (152, 121, 101)
# Valores RGB do pixel em ( 1279 ,  785 ): (145, 113, 102)
# Valores RGB do pixel em ( 1279 ,  786 ): (106, 74, 61)
# Valores RGB do pixel em ( 1279 ,  787 ): (113, 81, 66)
# Valores RGB do pixel em ( 1279 ,  788 ): (151, 122, 104)
# Valores RGB do pixel em ( 1279 ,  789 ): (152, 123, 105)
# Valores RGB do pixel em ( 1279 ,  790 ): (166, 139, 118)
# Valores RGB do pixel em ( 1279 ,  791 ): (139, 112, 91)
# Valores RGB do pixel em ( 1279 ,  792 ): (114, 90, 66)
# Valores RGB do pixel em ( 1279 ,  793 ): (94, 70, 46)
# Valores RGB do pixel em ( 1279 ,  794 ): (99, 74, 52)
# Valores RGB do pixel em ( 1279 ,  795 ): (80, 55, 33)
# Valores RGB do pixel em ( 1279 ,  796 ): (140, 115, 95)
# Valores RGB do pixel em ( 1279 ,  797 ): (135, 110, 90)
# Valores RGB do pixel em ( 1279 ,  798 ): (138, 113, 93)
# Valores RGB do pixel em ( 1279 ,  799 ): (102, 78, 54)
# Valores RGB do pixel em ( 1279 ,  800 ): (88, 63, 33)
# Valores RGB do pixel em ( 1279 ,  801 ): (145, 119, 86)
# Valores RGB do pixel em ( 1279 ,  802 ): (132, 107, 76)
# Valores RGB do pixel em ( 1279 ,  803 ): (116, 91, 60)
# Valores RGB do pixel em ( 1279 ,  804 ): (136, 113, 82)
# Valores RGB do pixel em ( 1279 ,  805 ): (124, 103, 76)
# Valores RGB do pixel em ( 1279 ,  806 ): (104, 84, 59)
# Valores RGB do pixel em ( 1279 ,  807 ): (104, 86, 64)
# Valores RGB do pixel em ( 1279 ,  808 ): (82, 67, 48)
# Valores RGB do pixel em ( 1279 ,  809 ): (94, 82, 66)
# Valores RGB do pixel em ( 1279 ,  810 ): (96, 88, 77)
# Valores RGB do pixel em ( 1279 ,  811 ): (65, 61, 52)
# Valores RGB do pixel em ( 1279 ,  812 ): (49, 46, 39)
# Valores RGB do pixel em ( 1279 ,  813 ): (53, 54, 48)
# Valores RGB do pixel em ( 1279 ,  814 ): (44, 46, 41)
# Valores RGB do pixel em ( 1279 ,  815 ): (32, 37, 33)
# Valores RGB do pixel em ( 1279 ,  816 ): (38, 40, 35)
# Valores RGB do pixel em ( 1279 ,  817 ): (36, 36, 34)
# Valores RGB do pixel em ( 1279 ,  818 ): (39, 38, 43)
# Valores RGB do pixel em ( 1279 ,  819 ): (34, 31, 38)
# Valores RGB do pixel em ( 1279 ,  820 ): (35, 27, 38)
# Valores RGB do pixel em ( 1279 ,  821 ): (43, 32, 40)
# Valores RGB do pixel em ( 1279 ,  822 ): (71, 55, 58)
# Valores RGB do pixel em ( 1279 ,  823 ): (126, 105, 100)
# Valores RGB do pixel em ( 1279 ,  824 ): (128, 102, 87)
# Valores RGB do pixel em ( 1279 ,  825 ): (130, 102, 80)
# Valores RGB do pixel em ( 1279 ,  826 ): (123, 96, 67)
# Valores RGB do pixel em ( 1279 ,  827 ): (89, 66, 35)
# Valores RGB do pixel em ( 1279 ,  828 ): (75, 58, 28)
# Valores RGB do pixel em ( 1279 ,  829 ): (89, 77, 51)
# Valores RGB do pixel em ( 1279 ,  830 ): (71, 65, 43)
# Valores RGB do pixel em ( 1279 ,  831 ): (43, 39, 27)
# Valores RGB do pixel em ( 1279 ,  832 ): (34, 30, 29)
# Valores RGB do pixel em ( 1279 ,  833 ): (30, 28, 33)
# Valores RGB do pixel em ( 1279 ,  834 ): (30, 25, 32)
# Valores RGB do pixel em ( 1279 ,  835 ): (48, 38, 49)
# Valores RGB do pixel em ( 1279 ,  836 ): (66, 54, 64)
# Valores RGB do pixel em ( 1279 ,  837 ): (92, 76, 86)
# Valores RGB do pixel em ( 1279 ,  838 ): (101, 85, 88)
# Valores RGB do pixel em ( 1279 ,  839 ): (71, 53, 53)
# Valores RGB do pixel em ( 1279 ,  840 ): (111, 94, 87)
# Valores RGB do pixel em ( 1279 ,  841 ): (111, 97, 86)
# Valores RGB do pixel em ( 1279 ,  842 ): (88, 76, 62)
# Valores RGB do pixel em ( 1279 ,  843 ): (69, 61, 48)
# Valores RGB do pixel em ( 1279 ,  844 ): (81, 74, 64)
# Valores RGB do pixel em ( 1279 ,  845 ): (84, 81, 74)
# Valores RGB do pixel em ( 1279 ,  846 ): (65, 64, 62)
# Valores RGB do pixel em ( 1279 ,  847 ): (53, 52, 50)
# Valores RGB do pixel em ( 1279 ,  848 ): (61, 60, 56)
# Valores RGB do pixel em ( 1279 ,  849 ): (45, 44, 40)
# Valores RGB do pixel em ( 1279 ,  850 ): (38, 34, 31)
# Valores RGB do pixel em ( 1279 ,  851 ): (50, 42, 40)
# Valores RGB do pixel em ( 1279 ,  852 ): (63, 53, 51)
# Valores RGB do pixel em ( 1279 ,  853 ): (72, 58, 55)
# Valores RGB do pixel em ( 1279 ,  854 ): (76, 61, 56)
# Valores RGB do pixel em ( 1279 ,  855 ): (82, 63, 57)
# Valores RGB do pixel em ( 1279 ,  856 ): (106, 83, 75)
# Valores RGB do pixel em ( 1279 ,  857 ): (111, 87, 75)
# Valores RGB do pixel em ( 1279 ,  858 ): (104, 78, 63)
# Valores RGB do pixel em ( 1279 ,  859 ): (94, 67, 48)
# Valores RGB do pixel em ( 1279 ,  860 ): (105, 77, 55)
# Valores RGB do pixel em ( 1279 ,  861 ): (134, 104, 78)
# Valores RGB do pixel em ( 1279 ,  862 ): (148, 117, 89)
# Valores RGB do pixel em ( 1279 ,  863 ): (142, 113, 81)
# Valores RGB do pixel em ( 1279 ,  864 ): (144, 122, 81)
# Valores RGB do pixel em ( 1279 ,  865 ): (100, 82, 44)
# Valores RGB do pixel em ( 1279 ,  866 ): (91, 73, 49)
# Valores RGB do pixel em ( 1279 ,  867 ): (90, 73, 63)
# Valores RGB do pixel em ( 1279 ,  868 ): (71, 55, 58)
# Valores RGB do pixel em ( 1279 ,  869 ): (56, 38, 50)
# Valores RGB do pixel em ( 1279 ,  870 ): (64, 43, 58)
# Valores RGB do pixel em ( 1279 ,  871 ): (95, 72, 82)
# Valores RGB do pixel em ( 1279 ,  872 ): (136, 112, 112)
# Valores RGB do pixel em ( 1279 ,  873 ): (165, 140, 133)
# Valores RGB do pixel em ( 1279 ,  874 ): (145, 119, 104)
# Valores RGB do pixel em ( 1279 ,  875 ): (103, 80, 62)
# Valores RGB do pixel em ( 1279 ,  876 ): (109, 88, 71)
# Valores RGB do pixel em ( 1279 ,  877 ): (114, 96, 82)
# Valores RGB do pixel em ( 1279 ,  878 ): (78, 64, 55)
# Valores RGB do pixel em ( 1279 ,  879 ): (41, 32, 25)
# Valores RGB do pixel em ( 1279 ,  880 ): (56, 53, 44)
# Valores RGB do pixel em ( 1279 ,  881 ): (71, 71, 61)
# Valores RGB do pixel em ( 1279 ,  882 ): (78, 75, 66)
# Valores RGB do pixel em ( 1279 ,  883 ): (46, 42, 33)
# Valores RGB do pixel em ( 1279 ,  884 ): (31, 24, 14)
# Valores RGB do pixel em ( 1279 ,  885 ): (43, 33, 23)
# Valores RGB do pixel em ( 1279 ,  886 ): (61, 47, 36)
# Valores RGB do pixel em ( 1279 ,  887 ): (95, 77, 65)
# Valores RGB do pixel em ( 1279 ,  888 ): (88, 66, 52)
# Valores RGB do pixel em ( 1279 ,  889 ): (96, 70, 53)
# Valores RGB do pixel em ( 1279 ,  890 ): (106, 80, 57)
# Valores RGB do pixel em ( 1279 ,  891 ): (131, 101, 75)
# Valores RGB do pixel em ( 1279 ,  892 ): (149, 118, 87)
# Valores RGB do pixel em ( 1279 ,  893 ): (145, 112, 77)
# Valores RGB do pixel em ( 1279 ,  894 ): (138, 104, 67)
# Valores RGB do pixel em ( 1279 ,  895 ): (148, 113, 75)
# Valores RGB do pixel em ( 1279 ,  896 ): (154, 116, 80)
# Valores RGB do pixel em ( 1279 ,  897 ): (154, 116, 80)
# Valores RGB do pixel em ( 1279 ,  898 ): (152, 117, 77)
# Valores RGB do pixel em ( 1279 ,  899 ): (151, 117, 72)
# Valores RGB do pixel em ( 1279 ,  900 ): (158, 126, 79)
# Valores RGB do pixel em ( 1279 ,  901 ): (169, 137, 88)
# Valores RGB do pixel em ( 1279 ,  902 ): (160, 129, 82)
# Valores RGB do pixel em ( 1279 ,  903 ): (138, 107, 60)
# Valores RGB do pixel em ( 1279 ,  904 ): (153, 120, 75)
# Valores RGB do pixel em ( 1279 ,  905 ): (147, 114, 71)
# Valores RGB do pixel em ( 1279 ,  906 ): (135, 101, 56)
# Valores RGB do pixel em ( 1279 ,  907 ): (171, 134, 89)
# Valores RGB do pixel em ( 1279 ,  908 ): (192, 154, 105)
# Valores RGB do pixel em ( 1279 ,  909 ): (185, 145, 93)
# Valores RGB do pixel em ( 1279 ,  910 ): (195, 154, 98)
# Valores RGB do pixel em ( 1279 ,  911 ): (188, 150, 88)
# Valores RGB do pixel em ( 1279 ,  912 ): (173, 146, 75)
# Valores RGB do pixel em ( 1279 ,  913 ): (143, 120, 50)
# Valores RGB do pixel em ( 1279 ,  914 ): (120, 96, 32)
# Valores RGB do pixel em ( 1279 ,  915 ): (139, 114, 58)
# Valores RGB do pixel em ( 1279 ,  916 ): (124, 97, 50)
# Valores RGB do pixel em ( 1279 ,  917 ): (103, 76, 33)
# Valores RGB do pixel em ( 1279 ,  918 ): (129, 102, 59)
# Valores RGB do pixel em ( 1279 ,  919 ): (133, 109, 63)
# Valores RGB do pixel em ( 1279 ,  920 ): (114, 92, 42)
# Valores RGB do pixel em ( 1279 ,  921 ): (127, 107, 54)
# Valores RGB do pixel em ( 1279 ,  922 ): (139, 122, 68)
# Valores RGB do pixel em ( 1279 ,  923 ): (136, 123, 71)
# Valores RGB do pixel em ( 1279 ,  924 ): (110, 97, 53)
# Valores RGB do pixel em ( 1279 ,  925 ): (67, 54, 19)
# Valores RGB do pixel em ( 1279 ,  926 ): (35, 24, 0)
# Valores RGB do pixel em ( 1279 ,  927 ): (33, 18, 0)
# Valores RGB do pixel em ( 1279 ,  928 ): (46, 24, 10)
# Valores RGB do pixel em ( 1279 ,  929 ): (173, 146, 137)
# Valores RGB do pixel em ( 1279 ,  930 ): (156, 127, 119)
# Valores RGB do pixel em ( 1279 ,  931 ): (95, 66, 58)
# Valores RGB do pixel em ( 1279 ,  932 ): (89, 60, 52)
# Valores RGB do pixel em ( 1279 ,  933 ): (78, 49, 41)
# Valores RGB do pixel em ( 1279 ,  934 ): (88, 58, 48)
# Valores RGB do pixel em ( 1279 ,  935 ): (108, 78, 67)
# Valores RGB do pixel em ( 1279 ,  936 ): (95, 66, 52)
# Valores RGB do pixel em ( 1279 ,  937 ): (157, 128, 112)
# Valores RGB do pixel em ( 1279 ,  938 ): (160, 129, 109)
# Valores RGB do pixel em ( 1279 ,  939 ): (140, 110, 86)
# Valores RGB do pixel em ( 1279 ,  940 ): (122, 92, 66)
# Valores RGB do pixel em ( 1279 ,  941 ): (133, 104, 74)
# Valores RGB do pixel em ( 1279 ,  942 ): (160, 129, 98)
# Valores RGB do pixel em ( 1279 ,  943 ): (119, 93, 56)
# Valores RGB do pixel em ( 1279 ,  944 ): (96, 77, 35)
# Valores RGB do pixel em ( 1279 ,  945 ): (76, 59, 16)
# Valores RGB do pixel em ( 1279 ,  946 ): (97, 83, 38)
# Valores RGB do pixel em ( 1279 ,  947 ): (98, 85, 40)
# Valores RGB do pixel em ( 1279 ,  948 ): (132, 121, 76)
# Valores RGB do pixel em ( 1279 ,  949 ): (82, 73, 30)
# Valores RGB do pixel em ( 1279 ,  950 ): (47, 39, 2)
# Valores RGB do pixel em ( 1279 ,  951 ): (62, 55, 26)
# Valores RGB do pixel em ( 1279 ,  952 ): (129, 123, 99)
# Valores RGB do pixel em ( 1279 ,  953 ): (115, 108, 90)
# Valores RGB do pixel em ( 1279 ,  954 ): (116, 108, 95)
# Valores RGB do pixel em ( 1279 ,  955 ): (103, 95, 84)
# Valores RGB do pixel em ( 1279 ,  956 ): (71, 61, 49)
# Valores RGB do pixel em ( 1279 ,  957 ): (70, 61, 46)
# Valores RGB do pixel em ( 1279 ,  958 ): (84, 75, 58)
# Valores RGB do pixel em ( 1279 ,  959 ): (74, 66, 47)
